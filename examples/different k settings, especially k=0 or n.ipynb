# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from agots.multivariate_generators.multivariate_data_generator import MultivariateDataGenerator

# %%
np.random.seed(1337)

STREAM_LENGTH = 200
N = 4
K = 2

dg = MultivariateDataGenerator(STREAM_LENGTH, N, K)
df = dg.generate_baseline(initial_value_min=-4, initial_value_max=4)

for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()

df.corr()
# Out:
#           x0        x1        x2        x3
# x0  1.000000  0.993202 -0.056126  0.460917
# x1  0.993202  1.000000 -0.053251  0.458618
# x2 -0.056126 -0.053251  1.000000 -0.324967
# x3  0.460917  0.458618 -0.324967  1.000000

# %%
np.random.seed(1337)

STREAM_LENGTH = 200
N = 4
K = 2

dg = MultivariateDataGenerator(STREAM_LENGTH, N, K)
df = dg.generate_baseline(initial_value_min=-4, initial_value_max=4)

for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()

df.corr()
# Out:
#           x0        x1        x2        x3
# x0  1.000000  0.993202 -0.056126  0.460917
# x1  0.993202  1.000000 -0.053251  0.458618
# x2 -0.056126 -0.053251  1.000000 -0.324967
# x3  0.460917  0.458618 -0.324967  1.000000

# %%
df = dg.add_outliers({'extreme': [{'n': 0, 'timestamps': [(10,), (30,)],
                                   'factor': 10
                                   }],
                      'shift':   [{'n': 1, 'timestamps': [(40, 60)],
                                   'factor': 10
                                   }],
                      'trend':   [{'n': 2, 'timestamps': [(70, 90)],
                                   'factor': 5
                                   }],
                      'variance': [{'n': 3, 'timestamps': [(100, 150)],
                                    'factor': 10
                                    }]})

for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()

# %%
np.random.seed(1337)

STREAM_LENGTH = 200
N = 4
K = 2

dg = MultivariateDataGenerator(STREAM_LENGTH, N, K)
df = dg.generate_baseline(initial_value_min=-4, initial_value_max=4)

for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()

df.corr()
# Out:
#           x0        x1        x2        x3
# x0  1.000000  0.993202 -0.056126  0.460917
# x1  0.993202  1.000000 -0.053251  0.458618
# x2 -0.056126 -0.053251  1.000000 -0.324967
# x3  0.460917  0.458618 -0.324967  1.000000

# %%
np.random.seed(1337)

STREAM_LENGTH = 200
N = 6
K = 4

dg = MultivariateDataGenerator(STREAM_LENGTH, N, K)
df = dg.generate_baseline(initial_value_min=-4, initial_value_max=4)

for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()

df.corr()
# Out:
#           x0        x1        x2        x3        x4        x5
# x0  1.000000  0.993202  0.993059  0.993129  0.460917  0.368422
# x1  0.993202  1.000000  0.998885  0.998841  0.458618  0.360972
# x2  0.993059  0.998885  1.000000  0.998912  0.456277  0.361869
# x3  0.993129  0.998841  0.998912  1.000000  0.461653  0.365812
# x4  0.460917  0.458618  0.456277  0.461653  1.000000  0.388697
# x5  0.368422  0.360972  0.361869  0.365812  0.388697  1.000000
